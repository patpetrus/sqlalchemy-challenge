# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")
conn = engine.connect()

#database_path = "../Resources/hawaii.sqlite"
#engine = create_engine(f"sqlite:///{database_path}")
#conn = engine.connect()

# %%
# View all of the classes that automap found
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# Get a list of column names and types
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Get a list of column names and types
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Save references to each table
station = Base.classes.station
measurement = Base.classes.measurement

# %%
# Create our session (link) from Python to the DB

from sqlalchemy.orm import Session
session = Session(bind=engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.

# recent_date = session.query(date).\
#    order_by(date.desc()).all

session.query(measurement.date).order_by(measurement.date.desc()).first()
# Out:
# ('2017-08-23')

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
# Calculate the date one year from the last date in data set.
query_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)
query_date
# Out:
# datetime.date(2016, 8, 23)

# %%
# Perform a query to retrieve the data and precipitation scores
data_precip = session.query(measurement.date, measurement.prcp).filter(measurement.date >=query_date).all()
data_precip
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
data_precip_df = pd.DataFrame(data_precip, columns = ['date', 'prcp'])
    
data_precip_df = data_precip_df.set_index('date')

data_precip_df
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-24  0.08
# 2016-08-25  0.08
# 2016-08-26  0.00
# 2016-08-27  0.00
# ...          ...
# 2017-08-19  0.09
# 2017-08-20   NaN
# 2017-08-21  0.56
# 2017-08-22  0.50
# 2017-08-23  0.45
#
# [2230 rows x 1 columns]

# %%
# Sort the dataframe by date
data_precip_df = data_precip_df.sort_values(by=['date'])
data_precip_df
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-23   NaN
# 2016-08-23  1.79
# 2016-08-23  0.05
# 2016-08-23  0.15
# ...          ...
# 2017-08-22  0.00
# 2017-08-23  0.00
# 2017-08-23  0.00
# 2017-08-23  0.08
# 2017-08-23  0.45
#
# [2230 rows x 1 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data
data_precip_df.plot(rot = 90)
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
data_precip_df.describe()
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
data_station = session.query(func.count(station.name)).all()
data_station
# Out:
# [(9)]

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
active = session.query(measurement.station, func.count(measurement.station)).group_by(measurement.station).\
order_by(func.count(measurement.station).desc()).all()
active
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
most_active_df = pd.DataFrame(data=active, columns=['Station', 'Count'])
most_active_df['Station'][0]
# Out:
# 'USC00519281'

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
calc_df = session.query(measurement.station, func.min(measurement.tobs), func.max(measurement.tobs), func.avg(measurement.tobs)).group_by(measurement.station).all()
calc_df('USC00519281')

#highest = session.query(measurement.station, func.max(measurement.tobs)).group_by(measurement.station).all()
#highest

#average = session.query(measurement.station, func.avg(measurement.tobs)).group_by(measurement.station).all()
#average

#lowest = session.query(measurement.station, func.avg(measurement.tobs)).group_by(measurement.station).all()
#lowest
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-3c62a2beda4b> in <module>
#       1 # Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
#       2 calc_df = session.query(measurement.station, func.min(measurement.tobs), func.max(measurement.tobs), func.avg(measurement.tobs)).group_by(measurement.station).all()
# ----> 3 calc_df('USC00519281')
#       4
#       5 #highest = session.query(measurement.station, func.max(measurement.tobs)).group_by(measurement.station).all()
#
# TypeError: 'list' object is not callable

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# find most recent date for station 
session.query(measurement.date).order_by(measurement.date.desc()).first()
# reset date numbers and go back one year by using the dt.timedelta function
query_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)
query_date
#query for the last 12 months of temperature data
data_precip = session.query(measurement.date, measurement.prcp).filter(measurement.date >=query_date).all()
data_precip
#convert data into df
data_precip_df = pd.DataFrame(data_precip, columns = ['date', 'prcp'])
data_precip_df = data_precip_df.set_index('date')
data_precip_df
#sort values by date so they show up on the graph in order
data_precip_df = data_precip_df.sort_values(by=['date'])
data_precip_df
#plot that mf
data_precip_df.plot(rot = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-73fdf5b1b176> in <module>
#       2 # Query the last 12 months of temperature observation data for this station and plot the results as a histogram
#       3
# ----> 4 twelve = session.query(measurement.date, measurement.prcp).sort_values(by=['date'])
#       5
#       6 # session.query(measurement.date).order_by(measurement.date.desc()).first()
#
# AttributeError: 'Query' object has no attribute 'sort_values'

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
